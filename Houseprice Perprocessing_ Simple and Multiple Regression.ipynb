# %%
# %pylab inline
import pandas as pd
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\Bhumihar Rakesh\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data=pd.read_csv("C:/Users/Bhumihar Rakesh/Desktop/Python/Deep Learning/ANN/Files 3/Data/House_Price.csv",header=0)
data
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0     24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1     21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2     34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3     33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4     36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
# ..     ...         ...         ...       ...       ...   ...    ...    ...
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
# ...

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
data.shape
# Out:
# (506, 19)

# %% [markdown]
# #Univariante Analysis= It ia a simplest form of analyzing data."uni" means one, in other words your data has only one variable
# It does not deal with cause and relatioships (unlike regression) and its major purpose is to describe, its takes data summarize
# that data and find patternn in data

# %%
data.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677082   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
sns.jointplot(data=data, x='n_hot_rooms', y= 'price')

# %% [markdown]
# Above garph we can see that we have 2 dots and it is outlier

# %%
sns.jointplot(data=data, x='rainfall', y='price')

# %% [markdown]
# Above garph we can see that we have all data b/w 20 n 60 but there is one dot and it shows that it is outlier

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
sns.countplot(data=data, x='airport')

# %%
sns.countplot(data=data,x='waterbody')

# %%
data.waterbody.value_counts()
# Out:
# River             183
# None              155
# Lake               97
# Lake and River     71
# Name: waterbody, dtype: int64

# %%
sns.countplot(data=data, x='bus_ter')

# %%
data.bus_ter.value_counts()
# Out:
# YES    506
# Name: bus_ter, dtype: int64

# %%
data.corr()
# Out:
#                 price  crime_rate  resid_area  air_qual  room_num       age  \
# price        1.000000   -0.389582   -0.484754 -0.429300  0.696304 -0.377999
# crime_rate  -0.389582    1.000000    0.406583  0.420972 -0.219247  0.352734
# resid_area  -0.484754    0.406583    1.000000  0.763651 -0.391676  0.644779
# air_qual    -0.429300    0.420972    0.763651  1.000000 -0.302188  0.731470
# room_num     0.696304   -0.219247   -0.391676 -0.302188  1.000000 -0.240265
# age         -0.377999    0.352734    0.644779  0.731470 -0.240265  1.000000
# dist1        0.251355   -0.380050   -0.706481 -0.768589  0.208464 -0.746904
# dist2        0.249459   -0.379813   -0.707956 -0.769724  0.203981 -0.746493
# dist3        0.246650   -0.380069   -0.707566 -0.769157  0.201907 -0.747021
# dist4        0.248200   -0.376462   -0.705819 -0.764873  0.205397 -0.746707
# teachers     0.505655   -0.289946   -0.383248 -0.188933  0.355501 -0.261515
# ...

# %% [raw]
# Few Observation
# missing values in n_hos_bed
# skewness or outlier in crime rate
# outlier in n_hot_room and rainfall
# Bus_ter has only one value" yes"

# %%
#Outlier Treatment

np.percentile(data.n_hot_rooms,[99])[0]
# Out:
# 15.399519999999999

# %%
uv=np.percentile(data.n_hot_rooms,[99])[0]

# %%
data[(data.n_hot_rooms>uv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# ...

# %%
data.n_hot_rooms[(data.n_hot_rooms>3*uv)]=3*uv
# Out:
# C:\Users\Bhumihar Rakesh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data[(data.n_hot_rooms>uv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394     46.19856
# 166   2.31   1.86      25.3       3.70     YES       8.300     15.40000
# 204   5.28   4.99      25.3       2.88     YES       8.900     15.40000
# 267   2.43   2.52      27.0       7.44     YES       8.000     15.40000
# 369   1.65   0.94      19.8       3.73     YES       6.700     15.40000
# ...

# %%
np.percentile(data.rainfall,[1])[0]
# Out:
# 20.0

# %%
lv=np.percentile(data.rainfall,[1])[0]

# %%
data[(data.rainfall<lv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None         3     YES  0.044019

# %%
data.rainfall[(data.rainfall<0.3*lv)]=0.3*lv
# Out:
# C:\Users\Bhumihar Rakesh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#Missing Value Treatment
data.n_hos_beds=data.n_hos_beds.fillna(data.n_hos_beds.mean())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   506 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
# Lets transform the varaible crime_rate 

sns.jointplot(data=data, x= 'crime_rate', y='price')

# %%
# As you can see that less the crime rate the price is higher and cirme rate is increaseing price is coming down,
# as above garph is making a ploynominal curve

# %%
#Let passing the number through log (log(0) Infinity, Log(1) zero)

data.crime_rate=np.log(1+data.crime_rate)

# %%
sns.jointplot(data=data, x= 'crime_rate', y='price')

# %%
#Now you can see that we have converted x into log () we can see that a relationship b/ x and y , and we dont see any outlier in above plot.
# This is how we have treated variable crime rate and outlier

# %%
# as we have combine the distance and created a new coloum avg_dist.

data['avg_dist']=(data.dist1+data.dist2+data.dist3+data.dist4)/4

# %%
data.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
# Now lets delete or drop the varaible

# %%
data=data.drop(columns=['dist1','dist2','dist3','dist4'])

# %%
#In colom Bus_ter we have seen that we have only one varaibel "yes" and we dont have enough infromation on coloum bus_ter, so delete

del data['bus_ter']

# %%
data.head(10)
# Out:
#    price  crime_rate  resid_area  air_qual  room_num    age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575   65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421   78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185   61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998   45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147   54.2      21.3
# 5   28.7    0.029413       32.18     0.458     6.430   58.7      21.3
# 6   22.9    0.084608       37.87     0.524     6.012   66.6      24.8
# 7   22.1    0.135012       37.87     0.524     6.172   96.1      24.8
# 8   16.5    0.191645       37.87     0.524     5.631  100.0      24.8
# 9   18.9    0.157038       37.87     0.524     6.004   85.9      24.8
#
#    poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall     parks  \
# 0       4.98     YES       5.480     11.19200     River        23  0.049347
# ...

# %%
#This is how you can see the catagorical variable in you data
data.airport.value_counts()
# Out:
# YES    279
# NO     227
# Name: airport, dtype: int64

# %%
data.waterbody.value_counts()
# Out:
# River             183
# None              155
# Lake               97
# Lake and River     71
# Name: waterbody, dtype: int64

# %%
#with below comand also you can see the catagorical varaiabe

data.select_dtypes(include=np.object)
# Out:
#     airport       waterbody
# 0       YES           River
# 1        NO            Lake
# 2        NO            None
# 3       YES            Lake
# 4        NO            Lake
# ..      ...             ...
# 501      NO  Lake and River
# 502     YES  Lake and River
# 503      NO            None
# 504     YES            None
# 505     YES            None
#
# [506 rows x 2 columns]

# %%
#Lets convert the cateogrical varaible into nymerical varaible
data=pd.get_dummies(data,drop_first=True)

# %%
data
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0     24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1     21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2     34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3     33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4     36.2    0.066770       32.18     0.458     7.147  54.2      21.3
# ..     ...         ...         ...       ...       ...   ...       ...
# 501   22.4    0.060747       41.93     0.573     6.593  69.1      19.0
# 502   20.6    0.044275       41.93     0.573     6.120  76.7      19.0
# 503   23.9    0.058986       41.93     0.573     6.976  91.0      19.0
# 504   22.0    0.103991       41.93     0.573     6.794  89.3      19.0
# 505   19.0    0.046320       41.93     0.573     6.030  80.8      19.0
#
#      poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# ...

# %%
#Corelation matrix 
data.corr()
# Out:
#                              price  crime_rate  resid_area  air_qual  \
# price                     1.000000   -0.466527   -0.484754 -0.429300
# crime_rate               -0.466527    1.000000    0.660283  0.707587
# resid_area               -0.484754    0.660283    1.000000  0.763651
# air_qual                 -0.429300    0.707587    0.763651  1.000000
# room_num                  0.696304   -0.288784   -0.391676 -0.302188
# age                      -0.377999    0.559591    0.644779  0.731470
# teachers                  0.505655   -0.390052   -0.383248 -0.188933
# poor_prop                -0.740836    0.608970    0.603800  0.590879
# n_hos_beds                0.108880   -0.004089    0.005799 -0.049553
# n_hot_rooms               0.017007    0.056570   -0.003761  0.007238
# rainfall                 -0.047200    0.082151    0.055845  0.091956
# parks                    -0.391574    0.638951    0.707635  0.915544
# avg_dist                  0.249289   -0.586371   -0.708022 -0.769247
# ...

# %%
#As we have seen now that we have hihgh (+ & -) corelation for variable room_num & poor_prop, ant the sam ewe can see that we have no corelation with n_hot_room
# and we can see that we have multicolineraaty b/w parks and air_qual and we can select any of then varaable for our dependent varaiable by checking the corelation
# as we can see that air_qual is high corelation with dependent varaible so we will delete park

# %%
del data['parks']

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_YES  \
# 0       4.98       5.480     11.19200        23    4.0875            1
# 1       9.14       7.332     12.17280        42    4.9675            0
# 2       4.03       7.394     46.19856        38    4.9675            0
# 3       2.94       9.268     11.26720        45    6.0650            1
# 4       5.33       8.824     11.28960        55    6.0625            0
#
#    waterbody_Lake and River  waterbody_None  waterbody_River
# 0                         0               0                1
# ...

# %%
#one of the way by which you can perform simple linear regression 
import statsmodels.api as sn

# %%
x=sn.add_constant(data['room_num'])

# %%
lm=sn.OLS(data['price'], x).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.485
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                     474.3
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           1.31e-74
# Time:                        18:00:24   Log-Likelihood:                -1671.6
# No. Observations:                 506   AIC:                             3347.
# Df Residuals:                     504   BIC:                             3356.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6592      2.642    -13.118      0.000     -39.850     -29.468
# ...

# %%
# Hear we will use SK learn library to perform linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
y=data['price']

# %%
X=data[['room_num']]

# %%
lm2=LinearRegression()

# %%
lm2.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm2.intercept_,lm2.coef_)
# Out:
# -34.659243123097184 [9.09966966]

# %%
lm2.predict(X)
# Out:
# array([25.17108491, 23.76973578, 30.72188341, 29.02024518, 30.37609596,
#        23.85163281, 20.04797089, 21.50391804, 16.58099675, 19.97517353,
#        23.36935032, 20.02067188, 18.92871152, 19.4746917 , 20.81234314,
#        18.42822969, 19.34729633, 19.84777816, 14.98855456, 17.45456504,
#        16.0259169 , 19.62028642, 21.23092795, 18.23713663, 19.24719996,
#        16.28980732, 18.23713663, 20.36645933, 24.44311134, 26.07195221,
#        17.32716966, 20.59395107, 19.48379137, 17.21797363, 20.81234314,
#        19.32909699, 18.49192738, 18.57382441, 19.62938609, 25.3530783 ,
#        29.25683659, 26.9455205 , 21.47661903, 21.85880515, 20.56665206,
#        17.0450799 , 17.99144555, 20.21176495, 14.46987339, 16.31710633,
#        19.60208708, 20.98523687, 24.58870605, 19.92057552, 18.91961185,
#        31.30426226, 23.42394834, 27.3641053 , 21.25822696, 19.27449897,
#        17.58196041, 19.62938609, 24.08822422, 26.87272314, 29.98481016,
# ...

# %%
help(sns.jointplot)
# Out:
# Help on function jointplot in module seaborn.axisgrid:
#
# jointplot(x, y, data=None, kind='scatter', stat_func=None, color=None, height=6, ratio=5, space=0.2, dropna=True, xlim=None, ylim=None, joint_kws=None, marginal_kws=None, annot_kws=None, **kwargs)
#     Draw a plot of two variables with bivariate and univariate graphs.
#
#     This function provides a convenient interface to the :class:`JointGrid`
#     class, with several canned plot kinds. This is intended to be a fairly
#     lightweight wrapper; if you need more flexibility, you should use
#     :class:`JointGrid` directly.
#
#     Parameters
#     ----------
#     x, y : strings or vectors
#         Data or names of variables in ``data``.
#     data : DataFrame, optional
#         DataFrame when ``x`` and ``y`` are variable names.
#     kind : { "scatter" | "reg" | "resid" | "kde" | "hex" }, optional
#         Kind of plot to draw.
#     stat_func : callable or None, optional
#         *Deprecated*
# ...

# %%
sns.jointplot(x=data['room_num'],y=data['price'],data=data,kind='reg')

# %%
# Multiple Linear Regression, droping coloum(axis=1), droping row(axis=0)

# %%
x_multi=data.drop('price', axis=1)

# %%
# Now we can see that price is droped 
x_multi.head()
# Out:
#    crime_rate  resid_area  air_qual  room_num   age  teachers  poor_prop  \
# 0    0.006300       32.31     0.538     6.575  65.2      24.7       4.98
# 1    0.026944       37.07     0.469     6.421  78.9      22.2       9.14
# 2    0.026924       37.07     0.469     7.185  61.1      22.2       4.03
# 3    0.031857       32.18     0.458     6.998  45.8      21.3       2.94
# 4    0.066770       32.18     0.458     7.147  54.2      21.3       5.33
#
#    n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_YES  \
# 0       5.480     11.19200        23    4.0875            1
# 1       7.332     12.17280        42    4.9675            0
# 2       7.394     46.19856        38    4.9675            0
# 3       9.268     11.26720        45    6.0650            1
# 4       8.824     11.28960        55    6.0625            0
#
#    waterbody_Lake and River  waterbody_None  waterbody_River
# 0                         0               0                1
# ...

# %%
y_multi=data['price']

# %%
y_multi.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: price, dtype: float64

# %%
x_multi_cons=sn.add_constant(x_multi)

# %%
x_multi_cons.head()
# Out:
#    const  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0    1.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1    1.0    0.026944       37.07     0.469     6.421  78.9      22.2
# 2    1.0    0.026924       37.07     0.469     7.185  61.1      22.2
# 3    1.0    0.031857       32.18     0.458     6.998  45.8      21.3
# 4    1.0    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_YES  \
# 0       4.98       5.480     11.19200        23    4.0875            1
# 1       9.14       7.332     12.17280        42    4.9675            0
# 2       4.03       7.394     46.19856        38    4.9675            0
# 3       2.94       9.268     11.26720        45    6.0650            1
# 4       5.33       8.824     11.28960        55    6.0625            0
#
#    waterbody_Lake and River  waterbody_None  waterbody_River
# 0                         0               0                1
# ...

# %%
lm_multi=sn.OLS(y_multi, x_multi_cons).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     84.34
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):          4.19e-125
# Time:                        18:00:27   Log-Likelihood:                -1516.6
# No. Observations:                 506   AIC:                             3065.
# Df Residuals:                     490   BIC:                             3133.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
#Let check via sklearn the multi regression

# %%
lm3= LinearRegression()

# %%
lm3.fit(x_multi, y_multi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm3.intercept_, lm3.coef_)
# Out:
# -6.23453913412909 [ 9.70998193e-03 -4.08746495e-02 -1.58973999e+01  4.01901676e+00
#  -5.71475069e-03  1.00700068e+00 -5.77271243e-01  3.29221139e-01
#   9.18675603e-02  1.61185504e-02 -1.21863952e+00  1.13151586e+00
#  -9.51641953e-01 -2.64086064e-01 -5.55404777e-01]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(x_multi, y_multi, test_size=0.2)

# %%
print(x_train.shape, x_test,shape, y_train.shape, y_test,shape)
# Out:
# (404, 15)      crime_rate  resid_area  air_qual  room_num    age  teachers  poor_prop  \
# 497    0.237740       39.69     0.585     5.794   70.6      20.8      14.10
# 415    2.948882       48.10     0.679     6.434  100.0      19.8      29.05
# 73     0.178472       40.81     0.413     6.245    6.2      20.8       7.54
# 383    2.196389       48.10     0.700     5.520  100.0      19.8      24.56
# 102    0.206006       38.56     0.520     6.405   85.4      19.1      10.63
# ..          ...         ...       ...       ...    ...       ...        ...
# 363    1.652955       48.10     0.770     5.803   89.0      19.8      14.64
# 84     0.049352       34.49     0.449     6.389   48.0      21.5       9.62
# 258    0.508930       33.97     0.647     7.333  100.0      27.0       7.79
# 199    0.031014       31.47     0.403     6.975   15.3      23.0       4.56
# 175    0.064514       34.05     0.510     6.546   33.1      23.4       5.33
#
# ...

# %%
lm_a=LinearRegression()

# %%
lm_a.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_test_a=lm_a.predict(x_test)

# %%
y_train_a=lm_a.predict(x_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_test_a)
# Out:
# 0.7411305111819617

# %%
r2_score(y_train, y_train_a)
# Out:
# 0.7113617486336347
